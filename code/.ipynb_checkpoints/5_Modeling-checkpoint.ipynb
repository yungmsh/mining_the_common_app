# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter, defaultdict
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import exploratory_analysis as ea
# %matplotlib inline

# %%
df = pd.read_csv('../data/train.csv', low_memory=False)
y = df.pop('top_school_final')

# %%
df, df_valid, y, y_valid = train_test_split(df, y, random_state=123)

# %% [markdown]
# ### Clean SAT

# %%
df['Highest Composite SAT Score'] = df['Highest Composite SAT Score'].apply(lambda x: None if x>2400 or x<600 else x)

# %%
df['SAT_total_temp'] = df['Highest SAT Scores'].apply(lambda x: ea.parseSAT(x) if type(x)==str else x)

# %%
ea.finalizeSAT(df)

# %%
SAT_median = df['SAT_total_final'].median()
df['SAT_total_final'].fillna(value=SAT_median, inplace=True)

# %% [markdown]
# ### SAT (times taken)

# %%
df['SAT_times_taken'] = df['How many times did you take the official SAT?'].copy()

# %%
SAT_times_median = df['SAT_times_taken'].median()
df['SAT_times_taken'].fillna(value=SAT_times_median, inplace=True)

# %% [markdown]
# ### Clean High School GPA

# %%
df['High School GPA'] = df['High School GPA'].apply(lambda x: np.nan if x==0 or x>100 else x)

# %%
df['High School GPA'] = df['High School GPA'].apply(lambda x: np.nan if x<=2 else x)

# %%
GPA_median = df[df['High School GPA']<=4]['High School GPA'].median()
df['High School GPA'] = df['High School GPA'].apply(lambda x: GPA_median if x>4 else x)

# %%
df['High School GPA'].fillna(value=GPA_median, inplace=True)

# %% [markdown]
# ### Gender

# %%
df['Male'] = df['Gender'].apply(lambda x: 1 if x=='Male' else 0)

# %% [markdown]
# ### Ethnicity

# %%
df['Ethnicity2'] = df['Ethnicity'].apply(lambda x: ea.parseEthnicity(x) if type(x)==str else x)

# %%
df['Ethnicity_Asian'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'asian' in x else 0)
df['Ethnicity_Black'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'black / african american' in x else 0)
df['Ethnicity_Hispanic'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'hispanic' in x else 0)
df['Ethnicity_White'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'white non-hispanic' in x else 0)
df['Ethnicity_Pacific'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'native hawaiian / pacific islander' in x else 0)
df['Ethnicity_NativeAm'] = df['Ethnicity2'].apply(lambda x: 1 if type(x)==list and 'native american' in x else 0)

# %% [markdown]
# ### High School Activities / Leadership / Honors

# %%
leader_words = ['leader','president','founder']
arts_words = ['arts', 'music', 'jazz', 'band', 'orchestra', 'choir', 'drama', 'theater']
award_words = ['award', 'scholarship', 'achievement', 'prize']
community_words = ['volunteer', 'community','cleanup', 'ngo', 'environment', 'humanity','green', 'charity']
academic_words = ['science', 'math', 'engineering']
gov_words = ['debate', 'model', 'government']
diversity_words = ['alliance', 'multicultural', 'diversity']
race_words = ['naacp','asian','jewish','german','french','japanese','italian','chinese']

# %%
ecc_colnames = ['leader','arts','award','community','academic','gov','diversity','race_ecc']
ecc_words = [leader_words, arts_words, award_words, community_words, academic_words, gov_words, diversity_words, race_words]
for colname, words in zip(ecc_colnames, ecc_words):
    df[colname] = df['High School Extracurricular Activities'].apply(lambda x: ea.parseECC(x, words))

# %% [markdown]
# ### Sports

# %%
all_sports = list(df['High School Sports Played'].apply(ea.getAllSports))
unique_sports = ea.getUniqueSports(all_sports)

# %%
# Initialize dummy variables for each sport category, set to 0s.
ea.makeSportsDummies(df, unique_sports)

# %%
# Fill in the dummy variables for each sport category accordingly (1 if that sport was played)
ea.parseSports(df, unique_sports)

# %%
# Create a varsity dummy variable that indicates if someone played sports at a varsity level
df['sportsVarsity'] = df['High School Sports Played'].apply(lambda x: ea.parseVarsity(x, unique_sports))
# Create a varsity dummy variable that indicates if someone was a captain of a sport
df['sportsCaptain'] = df['High School Sports Played'].apply(lambda x: ea.parseCaptain(x, unique_sports))

# %% [markdown]
# ### Home Country

# %%
df['Home Country'] = df['Home Country'].apply(lambda x:re.search('[[]\S+[]]\s[[]\S+[]]\s(.+)', x).group(1)
                                              if type(x)==str else x)

# %%
df['Home Country_US'] = df['Home Country'].apply(lambda x: 1 if x=='United States' else 0)

# %% [markdown]
# ### Academic Performance in HS

# %%
df = pd.get_dummies(df,columns=['Academic Performance in High School'], prefix='HS')

# %% [markdown]
# ### Final Columns

# %%
def getFinalCols(df):
    final_cols = ['SAT_total_final', 'SAT_times_taken', 'High School GPA', 'Male', 'leader', 'arts', 'award', 'community', 'academic', 'gov', 'diversity', 'race_ecc', 'Home Country_US']

    ethnicity_cols = [col for col in df.columns if col.find('Ethnicity_')>-1]
    HS_perf_cols = [col for col in df.columns if col.find('HS_')>-1]
    sports_cols = [col for col in df.columns if col.find('sports_')>-1]
    sports_cols.extend(['sportsVarsity', 'sportsCaptain'])
#     essay_cols = ['essay_topic'+str(i) for i in range(1,8)]

    final_cols.extend(ethnicity_cols)
    final_cols.extend(HS_perf_cols)
    final_cols.extend(sports_cols)
#     final_cols.extend(essay_cols)
    return final_cols

# %%
final_cols = getFinalCols(df)

# %% [markdown]
# ### StandardScale

# %%
scaler = StandardScaler()
# df = pd.DataFrame(scaler.fit_transform(df[final_cols]), columns=final_cols)

# %% [markdown]
# ### Logistic Regression -> Identify Least Useful Variables

# %% [markdown]
# #### Using statsmodels.api

# %%
logit = sm.Logit(y, df[final_cols])

# fit the model
result = logit.fit(method='powell',maxiter=500)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.320402
#          Iterations: 29
#          Function evaluations: 17692

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       top_school_final   No. Observations:                 9693
# Model:                          Logit   Df Residuals:                     9635
# Method:                           MLE   Df Model:                           57
# Date:                Mon, 14 Nov 2016   Pseudo R-squ.:                  0.1891
# Time:                        17:39:58   Log-Likelihood:                -3105.7
# converged:                       True   LL-Null:                       -3829.7
#                                         LLR p-value:                2.820e-265
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------
# SAT_total_final                     0.0029      0.000     15.244      0.000         0.003     0.003
# SAT_times_taken                    -0.6226      0.070     -8.863      0.000        -0.760    -0.485
# High School GPA                    -1.8579      0.105    -17.617      0.000        -2.065    -1.651
# Male                                0.2880      0.079      3.662      0.000         0.134     0.442
# leader                              0.7740      0.104      7.412      0.000         0.569     0.979
# arts                                0.0259      0.106      0.245      0.807        -0.181     0.233
# award                               0.2088      0.110      1.894      0.058        -0.007     0.425
# community                           0.0967      0.108      0.896      0.370        -0.115     0.308
# academic                            0.8219      0.128      6.442      0.000         0.572     1.072
# gov                                 0.4209      0.108      3.883      0.000         0.208     0.633
# diversity                           0.1151      0.202      0.571      0.568        -0.280     0.510
# race_ecc                           -0.0216      0.167     -0.130      0.897        -0.349     0.305
# Home Country_US                    -0.1467      0.082     -1.784      0.074        -0.308     0.014
# Ethnicity_Asian                    -0.0263      0.097     -0.270      0.787        -0.217     0.165
# Ethnicity_Black                    -0.9360      0.129     -7.262      0.000        -1.189    -0.683
# Ethnicity_Hispanic                 -0.4506      0.120     -3.743      0.000        -0.687    -0.215
# Ethnicity_White                    -0.7139      0.094     -7.555      0.000        -0.899    -0.529
# Ethnicity_Pacific                   0.1137      0.359      0.317      0.751        -0.589     0.816
# Ethnicity_NativeAm                 -0.2476      0.327     -0.758      0.448        -0.888     0.393
# HS_High at first but got worse     -0.6486      0.486     -1.335      0.182        -1.601     0.304
# HS_Low at first but improved       -0.5697      0.210     -2.708      0.007        -0.982    -0.157
# HS_Low one semester/year           -0.4045      0.264     -1.535      0.125        -0.921     0.112
# HS_Some good some bad              -1.1097      0.252     -4.407      0.000        -1.603    -0.616
# HS_Steady                           0.7411      0.099      7.474      0.000         0.547     0.935
# sports_Basketball                  -0.3721      0.198     -1.883      0.060        -0.759     0.015
# sports_Sailing                     -0.1493      0.723     -0.206      0.836        -1.566     1.268
# sports_Fencing                      1.0751      0.534      2.014      0.044         0.029     2.121
# sports_Tennis                      -0.1873      0.159     -1.177      0.239        -0.499     0.125
# sports_Hockey                       0.6010      0.565      1.063      0.288        -0.507     1.709
# sports_Rowing (Crew)               -0.2085      0.782     -0.267      0.790        -1.741     1.324
# sports_Water Polo                  -0.2337      0.410     -0.569      0.569        -1.038     0.571
# sports_Soccer                       0.1150      0.156      0.737      0.461        -0.191     0.421
# sports_Equestrian                  -0.3203      0.707     -0.453      0.651        -1.706     1.066
# sports_Football                    -0.3666      0.286     -1.283      0.200        -0.927     0.194
# sports_Squash                       0.0904      0.624      0.145      0.885        -1.132     1.313
# sports_Baseball                    -0.3167      0.305     -1.039      0.299        -0.914     0.281
# sports_Softball                    -0.0321      0.290     -0.110      0.912        -0.601     0.537
# sports_Mountain Biking/Cycling      2.2523      1.247      1.806      0.071        -0.191     4.696
# sports_Lacrosse                     0.5219      0.267      1.951      0.051        -0.002     1.046
# sports_Cross Country                0.1590      0.169      0.941      0.347        -0.172     0.490
# sports_Rugby                       -0.2731      0.795     -0.343      0.731        -1.832     1.285
# sports_Table Tennis (Ping Pong)     0.2363      0.742      0.319      0.750        -1.218     1.690
# sports_Rowing                       1.4101      0.670      2.106      0.035         0.098     2.723
# sports_Weight Lifting              -0.8844      1.192     -0.742      0.458        -3.222     1.453
# sports_Volleyball                  -0.1338      0.198     -0.674      0.500        -0.523     0.255
# sports_Drill                      -61.2761   1.45e+13  -4.21e-12      1.000     -2.85e+13  2.85e+13
# sports_Swimming/Diving             -0.0977      0.187     -0.523      0.601        -0.464     0.269
# sports_Field Hockey                -0.2974      0.654     -0.455      0.649        -1.579     0.984
# sports_Golf                         0.0808      0.328      0.246      0.805        -0.562     0.724
# sports_Track &amp; Field           -0.0133      0.148     -0.090      0.928        -0.304     0.277
# sports_Dance                       -0.1451      0.306     -0.474      0.635        -0.745     0.454
# sports_Wrestling                    0.3322      0.422      0.787      0.431        -0.495     1.159
# sports_Cheer/Spirit Squad          -0.6413      0.303     -2.113      0.035        -1.236    -0.047
# sports_Gymnastics                  -0.0488      0.567     -0.086      0.931        -1.160     1.063
# sports_Skiing                       0.9359      0.424      2.205      0.027         0.104     1.768
# sports_Martial Arts                 0.7764      0.407      1.909      0.056        -0.021     1.574
# sportsVarsity                       0.3427      0.123      2.796      0.005         0.102     0.583
# sportsCaptain                       0.4666      0.126      3.697      0.000         0.219     0.714
# ===================================================================================================
# """

# %% [markdown]
# #### Using sklearn

# %%
lr = LogisticRegression(penalty='l1')
lr.fit(df[final_cols], y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
def plotRegularization(df, y, alphas):
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(df)
    
    betas = []
    for a in alphas:
        lr = LogisticRegression(penalty='l1', C=a)
        lr.fit(X_scaled, y)
        betas.append(lr.coef_)    
    
    print betas
#     betas_t = np.array(betas).T
    
#     fig = plt.figure(figsize=(15,8))
#     for i,b in enumerate(betas_t):
#         plt.plot(b, label=df.columns.values[i])
#     plt.legend(ncol=4)
#     plt.title('L1 Regularization Effect on Beta Coefficients', fontdict={'fontsize':20, 'fontweight':'bold'})
#     plt.xlabel('Regularization')
#     plt.ylabel('Beta Coefficient')

# %%
alphas = np.logspace(-2,4,10)
plotRegularization(df[final_cols], y, alphas)
